# %% [markdown]
# This notebook was created for testing MEDCLIP

# %%
# !pip install --user torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch==2.2.2
#   Using cached https://download.pytorch.org/whl/cu121/torch-2.2.2%2Bcu121-cp311-cp311-win_amd64.whl (2454.8 MB)
# Collecting torchvision==0.17.2
#   Using cached https://download.pytorch.org/whl/cu121/torchvision-0.17.2%2Bcu121-cp311-cp311-win_amd64.whl (5.7 MB)
# Collecting torchaudio==2.2.2
#   Using cached https://download.pytorch.org/whl/cu121/torchaudio-2.2.2%2Bcu121-cp311-cp311-win_amd64.whl (4.1 MB)
# Requirement already satisfied: filelock in g:\anaconda3\lib\site-packages (from torch==2.2.2) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in g:\anaconda3\lib\site-packages (from torch==2.2.2) (4.9.0)
# Requirement already satisfied: sympy in g:\anaconda3\lib\site-packages (from torch==2.2.2) (1.12)
# Requirement already satisfied: networkx in g:\anaconda3\lib\site-packages (from torch==2.2.2) (3.1)
# Requirement already satisfied: jinja2 in g:\anaconda3\lib\site-packages (from torch==2.2.2) (3.1.3)
# Requirement already satisfied: fsspec in g:\anaconda3\lib\site-packages (from torch==2.2.2) (2023.10.0)
# Requirement already satisfied: numpy in c:\users\ninja\appdata\roaming\python\python311\site-packages (from torchvision==0.17.2) (1.24.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in g:\anaconda3\lib\site-packages (from torchvision==0.17.2) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in g:\anaconda3\lib\site-packages (from jinja2->torch==2.2.2) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in g:\anaconda3\lib\site-packages (from sympy->torch==2.2.2) (1.3.0)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-2.2.2+cu121 torchaudio-2.2.2+cu121 torchvision-0.17.2+cu121

# %%
import pandas as pd
from IPython.display import Image, display
import os
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the Dataset

# %%
data_directory = "../Datasets/ROCO2/"
df_train = pd.read_csv(data_directory + 'train_captions.csv')
df_train.head()
df_train['Image'] = df_train['ID'] + '.jpg'
df_train = df_train.drop(columns=['ID'])
df_train.head()
# Out:
#                                              Caption  \
# 0            Head CT demonstrating left parotiditis.
# 1  Acquired renal cysts in end-stage renal failur...
# 2  Computed tomography of the chest showing the r...
# 3  Lateral view of the sacrum showing the low con...
# 4  Thoracic CT scan showing perihilar pulmonary l...
#
#                           Image
# 0  ROCOv2_2023_train_000001.jpg
# 1  ROCOv2_2023_train_000002.jpg
# 2  ROCOv2_2023_train_000003.jpg
# 3  ROCOv2_2023_train_000004.jpg
# 4  ROCOv2_2023_train_000005.jpg

# %% [markdown]
# Exploratory Data Analysis

# %%
train_image_dir = data_directory +"train_images/train/"
img = Image.open(train_image_dir + df_train.iloc[0]['Image'])
plt.imshow(img, aspect='equal')

# %%
max_caption_length = df_train["Caption"].str.len().max()
print(max_caption_length)
# Out:
# 2854

# %%
# Shape of the DataFrame
print("Shape of the DataFrame:", df_train.shape)

# Summary of the DataFrame
print("\nDataFrame Info:")
print(df_train.info())

# First few rows of the DataFrame
print("\nFirst 5 Rows:")
print(df_train.head())

# Last few rows of the DataFrame
print("\nLast 5 Rows:")
print(df_train.tail())
# Out:
# Shape of the DataFrame: (60163, 2)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60163 entries, 0 to 60162
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Caption  60163 non-null  object
#  1   Image    60163 non-null  object
# dtypes: object(2)
# memory usage: 940.2+ KB
# None
#
# First 5 Rows:
#                                              Caption  \
# 0            Head CT demonstrating left parotiditis.
# 1  Acquired renal cysts in end-stage renal failur...
# 2  Computed tomography of the chest showing the r...
# 3  Lateral view of the sacrum showing the low con...
# 4  Thoracic CT scan showing perihilar pulmonary l...
#
#                           Image
# 0  ROCOv2_2023_train_000001.jpg
# 1  ROCOv2_2023_train_000002.jpg
# 2  ROCOv2_2023_train_000003.jpg
# 3  ROCOv2_2023_train_000004.jpg
# 4  ROCOv2_2023_train_000005.jpg
#
# Last 5 Rows:
#                                                  Caption  \
# 60158     CT section showing PD catheter in the bladder.
# 60159  X-ray kidney-ureter-bladder showing a left ren...
# 60160  Angiography film showing the pseudoaneurysm in...
# 60161  Film after glue embolization showing no fillin...
# 60162  Aortic angiogram showing small aneurysm involv...
#
#                               Image
# 60158  ROCOv2_2023_train_060159.jpg
# 60159  ROCOv2_2023_train_060160.jpg
# 60160  ROCOv2_2023_train_060161.jpg
# 60161  ROCOv2_2023_train_060162.jpg
# 60162  ROCOv2_2023_train_060163.jpg

# %%
# Check for missing values
print("\nMissing Values Count:")
print(df_train.isnull().sum())

# Check for duplicate rows
print("\nNumber of Duplicate Rows:", df_train.duplicated().sum())
# Out:
# Missing Values Count:
# Caption    0
# Image      0
# dtype: int64
#
# Number of Duplicate Rows: 0

# %%
# Removing rows with captions smaller than 10 characters
df_train = df_train[df_train['Caption'].str.len() >= 10]

# %%
# Summary statistics for all columns
print("\nSummary Statistics for All Columns:")
print(df_train.describe(include='all'))
# Out:
# Summary Statistics for All Columns:
#                               Caption                         Image
# count                           60122                         60122
# unique                          59813                         60122
# top     Initial panoramic radiograph.  ROCOv2_2023_train_000001.jpg
# freq                               37                             1

# %%
# !python -c "import torch; print(torch.__version__)"
# Out:
# 2.2.2+cu121

# %%
from medclip import MedCLIPModel, MedCLIPVisionModelViT
from medclip import MedCLIPProcessor
from transformers import CLIPProcessor, CLIPModel

# %%
# prepare for the demo image and texts
processor = MedCLIPProcessor()
image = Image.open(train_image_dir + df_train.iloc[0]['Image'])
inputs = processor(
    text=[df_train.iloc[0]['Caption']], 
    images=image, 
    return_tensors="pt", 
    padding=True
    )

# pass to MedCLIP model
model = MedCLIPModel(vision_cls=MedCLIPVisionModelViT)
model.from_pretrained()
model.cuda()
outputs = model(**inputs)
print(outputs.keys())
# dict_keys(['img_embeds', 'text_embeds', 'logits', 'loss_value', 'logits_per_text'])
# Out:
# C:\Users\ninja\AppData\Roaming\Python\Python311\site-packages\transformers\models\clip\feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# C:\Users\ninja\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       2 processor = MedCLIPProcessor()
#       3 image = Image.open(train_image_dir + df_train.iloc[0]['Image'])
# ----> 4 inputs = processor(
#       5     text=[df_train.iloc[0]['Caption']],
#       6     images=image,
#       7     return_tensors="pt",
#       8     padding=True
#       9     )
#      11 # pass to MedCLIP model
#      12 model = MedCLIPModel(vision_cls=MedCLIPVisionModelViT)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\models\clip\processing_clip.py:109, in CLIPProcessor.__call__(self, text, images, return_tensors, **kwargs)
#     106     encoding = self.tokenizer(text, return_tensors=return_tensors, **tokenizer_kwargs)
#     108 if images is not None:
# --> 109     image_features = self.image_processor(images, return_tensors=return_tensors, **image_processor_kwargs)
#     111 if text is not None and images is not None:
#     112     encoding["pixel_values"] = image_features.pixel_values
#
# File G:\anaconda3\Lib\site-packages\medclip\dataset.py:105, in MedCLIPFeatureExtractor.__call__(self, images, return_tensors, **kwargs)
#     103 # transformations (convert rgb + resizing + center cropping + normalization)
#     104 if self.do_convert_rgb:
# --> 105     images = [self.convert_rgb(image) for image in images]
#     107 if self.do_pad_square:
#     108     images = [self.pad_img(image,min_size=self.size) for image in images]
#
# File G:\anaconda3\Lib\site-packages\medclip\dataset.py:105, in <listcomp>(.0)
#     103 # transformations (convert rgb + resizing + center cropping + normalization)
#     104 if self.do_convert_rgb:
# --> 105     images = [self.convert_rgb(image) for image in images]
#     107 if self.do_pad_square:
#     108     images = [self.pad_img(image,min_size=self.size) for image in images]
#
# AttributeError: 'MedCLIPFeatureExtractor' object has no attribute 'convert_rgb'
